# %%
#script to read files (each file is a document content in raw json format) from a 
#specified folder and write to a MongoDB collection
#Have mongod.exe and mongo.exe running (in that order) when you execute this code

##Databases contains collections. A collection is made up of documents.
##Each document is made up of fields!

# %%
#using pymongo and json
import pymongo
import json

# %%
#Connection to Mongo DB
try:
    conn=pymongo.Connection()
    print "Connected successfully!!!"
except pymongo.errors.ConnectionFailure, e:
   print "Could not connect to MongoDB: %s" % e 
conn
# Out:
# Connected successfully!!!
# Connection('localhost', 27017)

# %%
#Set basepath
basepath = 'D:\Python\GET\data'

# %%
#Read filenames into file_names
file_names = []
#Set value for range; 1 for now - just read the first file
for j in range(4):
    for i in range(99):
        file_names.append(basepath+'\microsoft-excel_'+str(j)+'_'+str(i))

# %%
#Define my mongoDB database
db = conn.odesk_files

# %%
#Define my collection where I'll insert my search
#Get a collection
collection = db.my_collection

# %%
#Display database names created
conn.database_names()
# Out:
# [u'local', u'odesk_files', u'admin']

# %%
#Display collection names created
db.collection_names()
# Out:
# [u'system.indexes', u'my_collection']

# %%
#Remove database odesk_files
#conn.drop_database("odesk_files")
#check!
#conn.database_names()

# %%
#Delete a collection
#conn.odesk_files.drop_collection("my_collection")
#check!
#conn.odesk_files.collection_names()

# %%
#process each file sequentially
for i in range(len(file_names)):
    with open(file_names[i],'r') as record:
        data=record.read()
    ##print data to see what is read
    #print data
    #insert document into collection
    doc=json.loads(data)
    doc["rate"]=float(doc["rate"])
    collection.insert(doc)

# %%
#Display number of documents in the collection
collection.count()
# Out:
# 396

# %%
##Queries
#1. Number of Macedonian profiles
collection.find({"country": "Macedonia"}).count()
# Out:
# 2

# %%
#2. Names of those Macedonian members
search_docs = collection.find({"country": "Macedonia"})
for this_document in search_docs:
    print this_document["name"]
# Out:
# Vlado Mucunski
# Andrija Lutovac

# %%
#3. Number of Indian profiles specifying MS Excel as a skill
collection.find({"country": "India","skills": "microsoft-excel"}).count()
# Out:
# 42

# %%
#4. Using Regex to find a profiles which are hard-working
import re
regex = re.compile(r'hardworking|hard work|hard working')
rstats = collection.find({"description":regex}).count()
rstats
#print collection.find({"description":regex})
# Out:
# 44

# %%
#!5. Profiles created between specified dates
#from datetime import datetime
#date1 = datetime.strptime("June 17, 2010", "%B %e, %Y")
#date2 = datetime.strptime("August 20, 2011", "%B %e, %Y")
# Between 2 dates
#collection.find({"member_since": {"$gte": date1, "$lt": date2}}).count()

# %%
#6. What skills and categories do profiles with maximum rates have?
skillset=[]
type_of_work=[]
rates=[]
max_rate = collection.find().sort([("rate", pymongo.DESCENDING)]).limit(20)
for this_document in max_rate:
    print('\n')
    print this_document["skills"]
    skillset=skillset+this_document["skills"]
    print this_document["categories"]
    type_of_work=type_of_work+this_document["categories"]
    print this_document["rate"]
    rates.append(this_document["rate"])
import collections
counter1 = collections.Counter(skillset)
counter2 = collections.Counter(type_of_work)
counter3 = collections.Counter(rates)
print counter1.most_common() #WHY DOESN'T THIS PRINT?
print counter2.most_common()
print counter3.most_common()
# Out:
# [u'crystal-reports', u'oracle-database', u'sql', u'microsoft-excel']
# [u'Networking & Information Systems', u'Administrative Support', u'Business Services']
# 44.44
#
#
# [u'microsoft-excel', u'microsoft-access', u'microsoft-word', u'microsoft-powerpoint']
# [u'Administrative Support']
# 42.0
#
#
# [u'microsoft-excel', u'database-cataloguing']
# [u'Software Development', u'Writing & Translation', u'Administrative Support', u'Design & Multimedia', u'Sales & Marketing']
# 38.89
#
#
# [u'microsoft-powerpoint', u'microsoft-excel', u'microsoft-word', u'storyboarding', u'adobe-photoshop']
# [u'Design & Multimedia', u'Sales & Marketing']
# 38.89
#
#
# [u'vba', u'microsoft-excel']
# [u'Business Services']
# 33.33
#
#
# [u'vba', u'microsoft-access', u'microsoft-excel', u'microsoft-word', u'sql']
# [u'Web Development', u'Software Development', u'Customer Service', u'Business Services']
# 33.33
#
#
# [u'microsoft-excel']
# [u'Business Services']
# 33.33
#
#
# [u'editing', u'microsoft-powerpoint', u'microsoft-excel']
# [u'Writing & Translation', u'Administrative Support', u'Sales & Marketing']
# 31.11
#
#
# [u'microsoft-powerpoint', u'microsoft-word', u'microsoft-excel', u'presentations', u'presentation-design', u'research-papers', u'content-writing']
# [u'Writing & Translation', u'Design & Multimedia']
# 30.0
#
#
# [u'technical-writing', u'internet-research', u'blog-writing', u'microsoft-word', u'microsoft-powerpoint', u'microsoft-excel', u'website-development']
# [u'Web Development', u'Writing & Translation', u'Administrative Support', u'Design & Multimedia']
# 28.33
#
#
# [u'microsoft-excel']
# [u'Administrative Support']
# 27.78
#
#
# [u'autodesk', u'autolisp', u'lisp', u'microsoft-excel', u'vba']
# [u'Software Development', u'Design & Multimedia', u'Customer Service']
# 27.78
#
#
# [u'microsoft-excel', u'vba', u'sql', u'terrdata']
# [u'Software Development', u'Business Services']
# 27.78
#
#
# [u'ibm-spss', u'html', u'microsoft-word', u'microsoft-excel', u'microsoft-powerpoint', u'microsoft-publisher', u'microsoft-sharepoint-administration']
# [u'Writing & Translation', u'Administrative Support', u'Design & Multimedia', u'Business Services']
# 25.0
#
#
# [u'microsoft-excel']
# [u'Writing & Translation', u'Administrative Support', u'Business Services']
# 22.22
#
#
# [u'vba', u'microsoft-excel']
# [u'Software Development', u'Writing & Translation']
# 22.22
#
#
# [u'vba', u'scripting', u'microsoft-excel']
# [u'Software Development', u'Writing & Translation', u'Administrative Support']
# 22.22
#
#
# [u'customer-service', u'microsoft-word', u'microsoft-excel']
# [u'Administrative Support', u'Customer Service', u'Sales & Marketing', u'Business Services']
# 22.22
#
#
# [u'article-writing', u'internet-marketing', u'content-writing', u'microsoft-excel']
# [u'Web Development', u'Writing & Translation', u'Administrative Support', u'Sales & Marketing']
# 22.22
#
#
# [u'plc-programming', u'vba', u'microsoft-excel', u'technical-writing']
# [u'Software Development', u'Design & Multimedia']
# 22.22
# [(u'microsoft-excel', 20), (u'vba', 7), (u'microsoft-word', 7), (u'microsoft-powerpoint', 6), (u'sql', 3), (u'technical-writing', 2), (u'content-writing', 2), (u'microsoft-access', 2), (u'microsoft-publisher', 1), (u'autodesk', 1), (u'website-development', 1), (u'internet-marketing', 1), (u'oracle-database', 1), (u'ibm-spss', 1), (u'database-cataloguing', 1), (u'html', 1), (u'autolisp', 1), (u'article-writing', 1), (u'plc-programming', 1), (u'internet-research', 1), (u'blog-writing', 1), (u'scripting', 1), (u'terrdata', 1), (u'editing', 1), (u'crystal-reports', 1), (u'microsoft-sharepoint-administration', 1), (u'storyboarding', 1), (u'presentation-design', 1), (u'customer-service', 1), (u'research-papers', 1), (u'lisp', 1), (u'presentations', 1), (u'adobe-photoshop', 1)]
# [(u'Administrative Support', 11), (u'Writing & Translation', 9), (u'Business Services', 8), (u'Software Development', 7), (u'Design & Multimedia', 7), (u'Sales & Marketing', 5), (u'Customer Service', 3), (u'Web Development', 3), (u'Networking & Information Systems', 1)]
# [(22.22, 6), (33.33, 3), (27.78, 3), (38.89, 2), (28.33, 1), (42.0, 1), (44.44, 1), (31.11, 1), (25.0, 1), (30.0, 1)]

# %%
#Skills that get paid well
val_vec=[]
key_vec=[]
for key,val in counter1.items():
    val_vec.append(val)
    key_vec.append(key) 
        
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

y_pos = np.arange(len(key_vec))

plt.barh(y_pos, val_vec, xerr=0, align='center', alpha=0.7)
plt.yticks(y_pos, key_vec)
plt.xlabel('Skill frequency among profiles')
plt.title('Skills that get paid well')

plt.show()

# %%
#Categories that get paid well
val_vec=[]
key_vec=[]
for key,val in counter2.items():
    val_vec.append(val)
    key_vec.append(key) 
        
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

y_pos = np.arange(len(key_vec))

plt.barh(y_pos, val_vec, xerr=0, align='center', alpha=0.7)
plt.yticks(y_pos, key_vec)
plt.xlabel('Category frequency among profiles')
plt.title('Categories that get paid well')

plt.show()

# %%
#Histogram of rates
val_vec=[]
key_vec=[]

list=counter3.items()
list.sort(key=lambda x: [x[0]])
for key,val in list:
    val_vec.append(val)
    key_vec.append(key) 

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

y_pos = np.arange(len(key_vec))

plt.barh(y_pos, val_vec, xerr=0, align='center', alpha=0.7)
plt.yticks(y_pos, key_vec)
plt.xlabel('Rate frequency among profiles')
plt.title('Rates that are high')

plt.show()

# %%
#7. Demographics of the members (Top 30 countries by oDesk popularity)
countries=[]
country_list=collection.find()
for this_document in country_list:
    #print this_document["country"]
    countries.append(this_document["country"])
import collections
counter4 = collections.Counter(countries)
counter4.most_common(30)

val_vec=[]
key_vec=[]
for key,val in counter4.items():
    val_vec.append(val)
    key_vec.append(key) 
        
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

y_pos = np.arange(len(key_vec))

plt.barh(y_pos, val_vec, xerr=0, align='center', alpha=0.7)
plt.yticks(y_pos, key_vec)
plt.xlabel('Country frequency among profiles')
plt.title('Top 30 countries by oDesk popularity')

plt.show()
